# %% [markdown]
# <a href="https://colab.research.google.com/github/jadhavsiya481-hash/Python-Basic-Projects/blob/main/Special_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("netflix_dataset.csv")

# %%
df.head()
# Out:
#   show_id            title     type  release_year        genre country  \
# 0   s0001  Netflix Title 1    Movie          2010  Documentary   India
# 1   s0002  Netflix Title 2    Movie          2023        Drama     USA
# 2   s0003  Netflix Title 3    Movie          2016  Documentary   Spain
# 3   s0004  Netflix Title 4  TV Show          2010      Romance   Japan
# 4   s0005  Netflix Title 5    Movie          2016      Romance   India
#
#    rating  duration_min  views_millions
# 0     6.1            77           184.4
# 1     5.4            89           126.8
# 2     8.2           113            55.9
# 3     5.7           114            85.7
# 4     5.5           108            25.1

# %%
df.shape
# Out:
# (100, 9)

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'type', 'release_year', 'genre', 'country',
#        'rating', 'duration_min', 'views_millions'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id            object
# title              object
# type               object
# release_year        int64
# genre              object
# country            object
# rating            float64
# duration_min        int64
# views_millions    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# show_id           0
# title             0
# type              0
# release_year      0
# genre             0
# country           0
# rating            0
# duration_min      0
# views_millions    0
# dtype: int64

# %%
df.describe()
# Out:
#        release_year      rating  duration_min  views_millions
# count    100.000000  100.000000    100.000000      100.000000
# mean    2017.250000    7.212000    118.120000      128.775000
# std        4.515685    1.285842     33.573462       73.078645
# min     2010.000000    5.000000     62.000000        2.400000
# 25%     2013.000000    6.075000     89.000000       68.550000
# 50%     2017.500000    7.100000    116.000000      129.150000
# 75%     2021.000000    8.325000    145.250000      189.825000
# max     2025.000000    9.500000    180.000000      249.600000

# %%
#8
df["type"].value_counts().plot(kind="bar")
plt.title("Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns

sns.histplot(data=df, x='rating', bins=10)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["duration_min"],df["views_millions"])
plt.xlabel("Duration")
plt.ylabel("Views(Millions)")
plt.title("Duration vs Views")
plt.show()

# %%
plt.boxplot(df["duration_min"])
plt.title("Duration Boxplot")
plt.show()

# %%
import seaborn as sns

numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# DATASET SUMMARY
# This netflix dataset contains 100 racorrds and 9 columns. It is prfectly suitable for performing Exploratory Data Analysis
# and understanding patterns in the netflix content.

# Some of the KEY ATTRIBUTES are:
# 1.The dataset contains 100 titles.
# 2.There are 9 Attributes describing each title.
# 3.The ratings are generally between 5 to 9.
# 4.Duration varies across titles and views differ from one title to another.
# 5.Movies and TV Shows can be easily compared using the visualizations.
