# %% [markdown]
# <a href="https://colab.research.google.com/github/jadhavsiya481-hash/Python-Basic-Projects/blob/main/Session16%20Optional_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("fertility_dataset.xlsx")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            3       76             97             27      140  24.0
# 1            2      178             52             11       62  23.9
# 2            6      177             64             38      157  39.9
# 3            5      178             71             27       94  23.8
# 4            2      167             56             32      191  34.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     1.854   64        1
# 1                     1.288   22        1
# 2                     0.066   72        1
# 3                     1.921   27        1
# 4                     2.027   67        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 995            1      183             72             55      263  30.4
# 996            4      101             72             15      119  41.4
# 997            8      124             87             10      284  38.7
# 998            2      133             99             41       63  42.0
# 999            3      170             73             47       69  40.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                     0.326   67        1
# 996                     0.493   31        0
# 997                     0.492   79        1
# 998                     0.114   64        1
# 999                     0.427   26        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1000 non-null   int64
#  1   Glucose                   1000 non-null   int64
#  2   BloodPressure             1000 non-null   int64
#  3   SkinThickness             1000 non-null   int64
#  4   Insulin                   1000 non-null   int64
#  5   BMI                       1000 non-null   float64
#  6   DiabetesPedigreeFunction  1000 non-null   float64
#  7   Age                       1000 non-null   int64
#  8   Outcome                   1000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 70.4 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      7.584000   134.01600      79.629000      34.641000   159.588000
# std       4.561113    37.14436      17.495012      14.535453    82.833493
# min       0.000000    70.00000      50.000000      10.000000    15.000000
# 25%       4.000000   103.00000      65.000000      22.000000    86.000000
# 50%       8.000000   132.00000      79.000000      34.000000   161.500000
# 75%      11.000000   165.00000      95.000000      47.000000   229.250000
# max      15.000000   200.00000     110.000000      60.000000   300.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  1000.000000               1000.000000  1000.000000  1000.000000
# mean     31.409700                  1.289962    50.661000     0.839000
# std       7.903264                  0.692658    17.255545     0.367715
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.max(numeric_only=True)
df.min(numeric_only=True)
# Out:
# Pregnancies                  0.000
# Glucose                     70.000
# BloodPressure               50.000
# SkinThickness               10.000
# Insulin                     15.000
# BMI                         18.000
# DiabetesPedigreeFunction     0.057
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.mean(numeric_only=True)
# Out:
# Pregnancies                   7.584000
# Glucose                     134.016000
# BloodPressure                79.629000
# SkinThickness                34.641000
# Insulin                     159.588000
# BMI                          31.409700
# DiabetesPedigreeFunction      1.289962
# Age                          50.661000
# Outcome                       0.839000
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Pregnancies                   8.000
# Glucose                     132.000
# BloodPressure                79.000
# SkinThickness                34.000
# Insulin                     161.500
# BMI                          31.400
# DiabetesPedigreeFunction      1.311
# Age                          51.000
# Outcome                       1.000
# dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.026444      -0.007280       0.005596
# Glucose                      0.026444  1.000000       0.015538       0.027498
# BloodPressure               -0.007280  0.015538       1.000000       0.037190
# SkinThickness                0.005596  0.027498       0.037190       1.000000
# Insulin                     -0.020092 -0.047617      -0.004966       0.050355
# BMI                         -0.068971  0.006712      -0.026251      -0.059058
# DiabetesPedigreeFunction    -0.000060 -0.026458       0.002950       0.003778
# Age                          0.003904 -0.026309      -0.031546       0.021720
# Outcome                     -0.025649  0.295758      -0.016452      -0.065324
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.020092 -0.068971                 -0.000060
# ...

# %%
import matplotlib.pyplot as plt

df.select_dtypes(include='number').hist(figsize=(12,20))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,20))
sns.boxplot(df["SkinThickness"])
plt.title("SkinThickness")
plt.show()
